# %%
# Import necessary libraries 
import os
import numpy as np
import cv2 
import imutils
import numpy as np
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from tensorflow.keras.applications.vgg19 import preprocess_input
from tensorflow.keras.applications.vgg19 import VGG19
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D,Flatten,BatchNormalization,Dropout
from tensorflow.keras.models import Model
from tensorflow.keras import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import Callback
from tensorflow.keras.callbacks import ReduceLROnPlateau

# %%
# Define the path to the dataset
IMG_PATH = r'C:\Users\KIIT\Downloads\MINOR_TESTPHASE\brain_tumor_dataset'

# Create a list of all the image filenames
all_images = []
for folder in ['yes', 'no']:
    folder_path = os.path.join(IMG_PATH, folder)
    for filename in os.listdir(folder_path):
        
         all_images.append(os.path.join(folder_path, filename))

# Create a list of corresponding labels (0 for 'no', 1 for 'yes')
labels = [1 if 'Y' in filename else 0 for filename in all_images]

# Split the dataset into train, validation, and test sets
X_train_val, X_test, y_train_val, y_test = train_test_split(all_images, labels, test_size=0.4, random_state=123)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=123)

# Print the sizes of the resulting datasets
print(f'Train set size: {len(X_train)}')
print(f'Validation set size: {len(X_val)}')
print(f'Test set size: {len(X_test)}')
# Out:
# Train set size: 113
# Validation set size: 38
# Test set size: 102

# %%
# %matplotlib inline

# Define the path to the dataset
IMG_PATH = r'C:\Users\KIIT\Downloads\MINOR_TESTPHASE\brain_tumor_dataset'

# Define the labels and their corresponding colors
labels = {0: 'No', 1: 'Yes'}
colors = {0: 'blue', 1: 'red'}

# Plot some images from the train set for each label
fig, axs = plt.subplots(2, 3, figsize=(10, 8))
for i, label in enumerate([0, 1]):
    images = [x for x, y in zip(X_train, y_train) if y == label][:3]
    for j, image_path in enumerate(images):
        img = plt.imread(image_path)
        axs[i, j].imshow(img)
        axs[i, j].set_title(labels[label], color=colors[label])
plt.show()

# %%
def preprocess_images(images):
    preprocessed_images = []
    for i, img_path in enumerate(images):
        img = cv2.imread(img_path)
        img = cv2.resize(
            img,
            dsize=(224,224),
            interpolation=cv2.INTER_CUBIC
        )
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        gray = cv2.GaussianBlur(gray, (5, 5), 0)

        # threshold the image, then perform a series of erosions +
        # dilations to remove any small regions of noise
        thresh = cv2.threshold(gray, 45, 255, cv2.THRESH_BINARY)[1]
        thresh = cv2.erode(thresh, None, iterations=2)
        thresh = cv2.dilate(thresh, None, iterations=2)

        # find contours in thresholded image, then grab the largest one
        cnts = cv2.findContours(thresh.copy(), cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
        cnts = imutils.grab_contours(cnts)
        c = max(cnts, key=cv2.contourArea)

        # find the extreme points
        extLeft = tuple(c[c[:, :, 0].argmin()][0])
        extRight = tuple(c[c[:, :, 0].argmax()][0])
        extTop = tuple(c[c[:, :, 1].argmin()][0])
        extBot = tuple(c[c[:, :, 1].argmax()][0])

        # crop
        ADD_PIXELS = 0
        new_img = img[extTop[1]-ADD_PIXELS:extBot[1]+ADD_PIXELS, extLeft[0]-ADD_PIXELS:extRight[0]+ADD_PIXELS].copy()
        new_img = cv2.resize(
            new_img,
            dsize=(224,224))
        preprocessed_images.append(new_img)
    return np.array(preprocessed_images)

# %%
# Apply the preprocessing to all the data subsets 
X_train_pre = preprocess_images(X_train)
X_val_pre = preprocess_images(X_val)
X_test_pre = preprocess_images(X_test)

# %%
# Transform the subsets to numpy arrays 
X_train_pre_vgg = np.array([preprocess_input(image) for image in X_train_pre])
X_val_pre_vgg = np.array([preprocess_input(image) for image in X_val_pre])
X_test_pre_vgg = np.array([preprocess_input(image) for image in X_test_pre])

# %%
# plot some images from X_train_pre
import matplotlib.pyplot as plt
from skimage import exposure

plt.figure(figsize=(5, 5))
for i in range(9):
    img = exposure.rescale_intensity(X_train_pre_vgg[i], out_range=(0, 1))
    plt.subplot(3, 3, i+1)
    plt.imshow(img, cmap='gray')
plt.show()

# %%
# Load the pre-trained VGG19 model
base_model = VGG19(
weights='imagenet',
include_top=False,
input_shape=(224,224) + (3,)
)

# Create a new model by adding a few layers on top of the pre-trained model
model = Sequential()
model.add(base_model)
model.add(Flatten())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# Freeze the weights of the pre-trained model
model.layers[0].trainable = False

# Compile the model with appropriate loss function, optimizer and metrics
model.compile(
loss='binary_crossentropy',
optimizer=Adam(),
metrics=['accuracy']
)

# Print the summary of the model
model.summary()

# Define the training data generator with necessary data augmentation techniques
train_datagen = ImageDataGenerator(
rescale=1./255,
rotation_range=20,
width_shift_range=0.1,
height_shift_range=0.1,
shear_range=0.2,
zoom_range=0.2,
horizontal_flip=True,
fill_mode='nearest'
)

# Create the training data generator using the training dataset and the data generator
train_generator = train_datagen.flow(
X_train_pre_vgg,
y_train,
batch_size=32
)

# Define a callback to reduce the learning rate when the validation accuracy plateaus
reduce_lr = ReduceLROnPlateau(monitor='val_accuracy', factor=0.5, patience=5, min_lr=1e-5)

# Define a callback to stop the training when validation accuracy reaches 90%
class StopOnAccuracy(Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('accuracy') > 0.88:
            print("\nReached 90% accuracy, stopping training...")
            self.model.stop_training = True

# Define the validation data generator with appropriate data preprocessing
val_datagen = ImageDataGenerator(rescale=1./255)

# Create the validation data generator using the validation dataset and the data generator
val_generator = val_datagen.flow(X_val_pre_vgg, y_val, batch_size=18)

# Train the model using the training data generator, validation data generator and the defined callbacks
history = model.fit(
train_generator,
epochs=50,
validation_data=val_generator,
callbacks=[reduce_lr,StopOnAccuracy()]
)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg19 (Functional)          (None, 7, 7, 512)         20024384
#
#  flatten_1 (Flatten)         (None, 25088)             0
#
#  dropout_1 (Dropout)         (None, 25088)             0
#
#  dense_1 (Dense)             (None, 1)                 25089
#
# =================================================================
# Total params: 20,049,473
# Trainable params: 25,089
# Non-trainable params: 20,024,384
# _________________________________________________________________
# Epoch 1/50
# 4/4 [==============================] - 67s 16s/step - loss: 1.2110 - accuracy: 0.5575 - val_loss: 0.7464 - val_accuracy: 0.4211 - lr: 0.0010
# Epoch 2/50
# 4/4 [==============================] - 65s 19s/step - loss: 0.9010 - accuracy: 0.5398 - val_loss: 0.7121 - val_accuracy: 0.6579 - lr: 0.0010
# Epoch 3/50
# 4/4 [==============================] - 66s 17s/step - loss: 0.6448 - accuracy: 0.7080 - val_loss: 1.0060 - val_accuracy: 0.6579 - lr: 0.0010
# Epoch 4/50
# 4/4 [==============================] - 66s 17s/step - loss: 0.5686 - accuracy: 0.7434 - val_loss: 0.5898 - val_accuracy: 0.7105 - lr: 0.0010
# Epoch 5/50
# 4/4 [==============================] - 64s 17s/step - loss: 0.6847 - accuracy: 0.6195 - val_loss: 0.6670 - val_accuracy: 0.6316 - lr: 0.0010
# Epoch 6/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.4858 - accuracy: 0.7788 - val_loss: 0.7110 - val_accuracy: 0.6842 - lr: 0.0010
# Epoch 7/50
# 4/4 [==============================] - 66s 17s/step - loss: 0.4799 - accuracy: 0.7788 - val_loss: 0.5514 - val_accuracy: 0.7105 - lr: 0.0010
# Epoch 8/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.5542 - accuracy: 0.7434 - val_loss: 0.5925 - val_accuracy: 0.6316 - lr: 0.0010
# Epoch 9/50
# 4/4 [==============================] - 66s 19s/step - loss: 0.4650 - accuracy: 0.7699 - val_loss: 0.6898 - val_accuracy: 0.6842 - lr: 0.0010
# Epoch 10/50
# 4/4 [==============================] - 72s 19s/step - loss: 0.4494 - accuracy: 0.7611 - val_loss: 0.5598 - val_accuracy: 0.6579 - lr: 5.0000e-04
# Epoch 11/50
# 4/4 [==============================] - 88s 22s/step - loss: 0.4222 - accuracy: 0.7876 - val_loss: 0.5294 - val_accuracy: 0.6842 - lr: 5.0000e-04
# Epoch 12/50
# 4/4 [==============================] - 64s 16s/step - loss: 0.3689 - accuracy: 0.8230 - val_loss: 0.5370 - val_accuracy: 0.7105 - lr: 5.0000e-04
# Epoch 13/50
# 4/4 [==============================] - 61s 16s/step - loss: 0.4308 - accuracy: 0.7876 - val_loss: 0.5814 - val_accuracy: 0.6579 - lr: 5.0000e-04
# Epoch 14/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.4187 - accuracy: 0.7965 - val_loss: 0.5378 - val_accuracy: 0.7105 - lr: 5.0000e-04
# Epoch 15/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3209 - accuracy: 0.8938 - val_loss: 0.5299 - val_accuracy: 0.7368 - lr: 2.5000e-04
# Epoch 16/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.4417 - accuracy: 0.7611 - val_loss: 0.5521 - val_accuracy: 0.6842 - lr: 2.5000e-04
# Epoch 17/50
# 4/4 [==============================] - 68s 18s/step - loss: 0.3837 - accuracy: 0.8142 - val_loss: 0.5544 - val_accuracy: 0.6842 - lr: 2.5000e-04
# Epoch 18/50
# 4/4 [==============================] - 68s 17s/step - loss: 0.3812 - accuracy: 0.8319 - val_loss: 0.5465 - val_accuracy: 0.6842 - lr: 2.5000e-04
# Epoch 19/50
# 4/4 [==============================] - 68s 17s/step - loss: 0.3615 - accuracy: 0.8407 - val_loss: 0.5423 - val_accuracy: 0.7105 - lr: 2.5000e-04
# Epoch 20/50
# 4/4 [==============================] - 67s 17s/step - loss: 0.3363 - accuracy: 0.8584 - val_loss: 0.5133 - val_accuracy: 0.7368 - lr: 2.5000e-04
# Epoch 21/50
# 4/4 [==============================] - 68s 20s/step - loss: 0.3416 - accuracy: 0.8673 - val_loss: 0.5052 - val_accuracy: 0.7368 - lr: 1.2500e-04
# Epoch 22/50
# 4/4 [==============================] - 65s 17s/step - loss: 0.3842 - accuracy: 0.8142 - val_loss: 0.5143 - val_accuracy: 0.7368 - lr: 1.2500e-04
# Epoch 23/50
# 4/4 [==============================] - 66s 17s/step - loss: 0.3820 - accuracy: 0.8407 - val_loss: 0.5238 - val_accuracy: 0.7368 - lr: 1.2500e-04
# Epoch 24/50
# 4/4 [==============================] - 66s 17s/step - loss: 0.3651 - accuracy: 0.8496 - val_loss: 0.5471 - val_accuracy: 0.6842 - lr: 1.2500e-04
# Epoch 25/50
# 4/4 [==============================] - 64s 17s/step - loss: 0.3018 - accuracy: 0.8938 - val_loss: 0.5459 - val_accuracy: 0.6842 - lr: 1.2500e-04
# Epoch 26/50
# 4/4 [==============================] - 67s 17s/step - loss: 0.3693 - accuracy: 0.8496 - val_loss: 0.5457 - val_accuracy: 0.6842 - lr: 6.2500e-05
# Epoch 27/50
# 4/4 [==============================] - 65s 17s/step - loss: 0.3520 - accuracy: 0.8053 - val_loss: 0.5453 - val_accuracy: 0.7105 - lr: 6.2500e-05
# Epoch 28/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3486 - accuracy: 0.8584 - val_loss: 0.5415 - val_accuracy: 0.7105 - lr: 6.2500e-05
# Epoch 29/50
# 4/4 [==============================] - 65s 16s/step - loss: 0.3856 - accuracy: 0.8230 - val_loss: 0.5313 - val_accuracy: 0.7368 - lr: 6.2500e-05
# Epoch 30/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3902 - accuracy: 0.8407 - val_loss: 0.5234 - val_accuracy: 0.7368 - lr: 6.2500e-05
# Epoch 31/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3926 - accuracy: 0.7965 - val_loss: 0.5273 - val_accuracy: 0.7368 - lr: 3.1250e-05
# Epoch 32/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3689 - accuracy: 0.8319 - val_loss: 0.5334 - val_accuracy: 0.7368 - lr: 3.1250e-05
# Epoch 33/50
# 4/4 [==============================] - 62s 18s/step - loss: 0.3592 - accuracy: 0.8053 - val_loss: 0.5371 - val_accuracy: 0.7368 - lr: 3.1250e-05
# Epoch 34/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3411 - accuracy: 0.8584 - val_loss: 0.5358 - val_accuracy: 0.7368 - lr: 3.1250e-05
# Epoch 35/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3473 - accuracy: 0.8319 - val_loss: 0.5318 - val_accuracy: 0.7368 - lr: 3.1250e-05
# Epoch 36/50
# 4/4 [==============================] - 62s 18s/step - loss: 0.3936 - accuracy: 0.8142 - val_loss: 0.5309 - val_accuracy: 0.7368 - lr: 1.5625e-05
# Epoch 37/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3784 - accuracy: 0.8407 - val_loss: 0.5313 - val_accuracy: 0.7368 - lr: 1.5625e-05
# Epoch 38/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3716 - accuracy: 0.8230 - val_loss: 0.5303 - val_accuracy: 0.7368 - lr: 1.5625e-05
# Epoch 39/50
# 4/4 [==============================] - 63s 18s/step - loss: 0.3604 - accuracy: 0.8496 - val_loss: 0.5280 - val_accuracy: 0.7368 - lr: 1.5625e-05
# Epoch 40/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3435 - accuracy: 0.8407 - val_loss: 0.5271 - val_accuracy: 0.7368 - lr: 1.5625e-05
# Epoch 41/50
# 4/4 [==============================] - 64s 16s/step - loss: 0.3267 - accuracy: 0.8673 - val_loss: 0.5258 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 42/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3656 - accuracy: 0.8230 - val_loss: 0.5257 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 43/50
# 4/4 [==============================] - 61s 18s/step - loss: 0.3143 - accuracy: 0.8761 - val_loss: 0.5252 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 44/50
# 4/4 [==============================] - 64s 16s/step - loss: 0.3141 - accuracy: 0.8319 - val_loss: 0.5253 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 45/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3886 - accuracy: 0.8142 - val_loss: 0.5259 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 46/50
# 4/4 [==============================] - 63s 16s/step - loss: 0.3865 - accuracy: 0.8053 - val_loss: 0.5274 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 47/50
# 4/4 [==============================] - 64s 16s/step - loss: 0.3580 - accuracy: 0.8584 - val_loss: 0.5278 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 48/50
# 4/4 [==============================] - 64s 16s/step - loss: 0.4010 - accuracy: 0.8053 - val_loss: 0.5278 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 49/50
# 4/4 [==============================] - 65s 17s/step - loss: 0.3264 - accuracy: 0.8673 - val_loss: 0.5267 - val_accuracy: 0.7368 - lr: 1.0000e-05
# Epoch 50/50
# 4/4 [==============================] - 62s 16s/step - loss: 0.3274 - accuracy: 0.8850 - val_loss: 0.5280 - val_accuracy: 0.7368 - lr: 1.0000e-05

# %%
# Plot the training and validation accuracy curves
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# Plot the training and validation loss curves
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()

# %%
# Make predictions on X_test_pre
y_pred = model.predict(X_test_pre)
y_pred = np.round(y_pred).astype(int)

# Plot confusion matrix
from sklearn.metrics import confusion_matrix, accuracy_score
import seaborn as sns

cm = confusion_matrix(y_test, y_pred)

sns.heatmap(cm, annot=True, cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()
# Out:
# 4/4 [==============================] - 44s 10s/step

# %%
#kapa score
from sklearn.metrics import cohen_kappa_score

# Calculate Cohen's kappa coefficient
kappa = cohen_kappa_score(y_test, y_pred)

# Print kappa score
print('Kappa score:', kappa)
# Out:
# Kappa score: 0.3833131801692865

# %%
#F1.score
from sklearn.metrics import f1_score

# Make predictions on X_test_pre
y_pred = model.predict(X_test_pre)
y_pred = np.round(y_pred).astype(int)

# Calculate F1 score
f1 = f1_score(y_test, y_pred)

print('F1 score:', f1)
# Out:
# 4/4 [==============================] - 40s 9s/step
# F1 score: 0.7794117647058824

# %%
#Recall
from sklearn.metrics import recall_score

recall = recall_score(y_test, y_pred)
print('Recall:', recall)
# Out:
# Recall: 0.9636363636363636

# %%
#precision
from sklearn.metrics import precision_score

precision = precision_score(y_test, y_pred)
print('Precision:', precision)
# Out:
# Precision: 0.654320987654321

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, y_pred)
print('Accuracy:', accuracy)
# Out:
# Accuracy: 0.7058823529411765
